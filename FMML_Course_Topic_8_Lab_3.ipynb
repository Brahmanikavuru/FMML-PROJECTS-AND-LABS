# %% [markdown]
# <a href="https://colab.research.google.com/github/Brahmanikavuru/FMML-PROJECTS-AND-LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 16:50:57--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   206MB/s    in 0.3s
#
# 2024-04-03 16:50:58 (206 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 623    1609.08337v1  Research on multilingual speech recognition re...    cs
# 29640  1710.00187v1  Unsupervised segmentation of action segments i...    cs
# 2491    1310.7163v1  Thompson Sampling, one of the oldest heuristic...    cs
# 3662   1612.04418v1  Despite the growing importance of multilingual...    cs
# 18154  cs/0410033v2  This paper may look like a glossary of the fus...    cs
# ...             ...                                                ...   ...
# 40257  1802.09298v1  This paper introduces geometry and object shap...    cs
# 29257  1708.09006v1  An efficient, fully automatic method for 3D fa...    cs
# 3238   1502.04837v2  In our physically inspired in-tree (IT) based ...  stat
# 22322  1602.00229v1  Most signal processing problems involve the ch...  stat
# 18110  cs/0404011v1  This document describes syntax, semantics and ...    cs
#
#                                                    title  year  \
# 623    Multi-task Recurrent Model for True Multilingu...  2016
# 29640  Unsupervised Segmentation of Action Segments i...  2017
# 2491   Generalized Thompson Sampling for Contextual B...  2013
# 3662   User Model-Based Intent-Aware Metrics for Mult...  2016
# 18154  An In-Depth Look at Information Fusion Rules &...  2004
# ...                                                  ...   ...
# 40257  Beyond Pixels: Leveraging Geometry and Shape C...  2018
# 29257          Pix2face: Direct 3D Face Model Estimation  2017
# 3238   Nonparametric Nearest Neighbor Descent Cluster...  2015
# 22322  Iterative Gaussianization: from ICA to Random ...  2016
# 18110  Parametric external predicates for the DLV System  2004
#
#                                                 keywords
# 623    [multilingual, recognition, attractive, challe...
# 29640  [unsupervised, segmentation, egocentric, desir...
# 2491   [heuristics, demonstrate, performance, empiric...
# 3662   [importance, multilingual, appropriate, prefer...
# 18154  [introduce, presenting, conjunctive, disjuncti...
# ...                                                  ...
# 40257  [introduces, scenarios, monocular, association...
# 29257  [efficient, automatic, estimation, unconstrain...
# 3238   [physically, clustering, algorithm, parameter,...
# 22322  [processing, challenging, multidimensional, pr...
# 18110  [describes, semantics, implementation, guideli...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 623      [multilingual, recognition, attractive, challe...
# 29640    [unsupervised, segmentation, egocentric, desir...
# 2491     [heuristics, demonstrate, performance, empiric...
# 3662     [importance, multilingual, appropriate, prefer...
# 18154    [introduce, presenting, conjunctive, disjuncti...
#                                ...
# 23349    [construction, convolution, extensively, convo...
# 7228     [inferring, dimensional, uncertain, measuremen...
# 5897     [representations, distributions, clustering, c...
# 9386     [recommendation, emphcontent, increased, adver...
# 23840    [iterative, particular, collinear, representat...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8689 words.
# Out of those 4568 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ff2450ea-4048-4ccb-bc4e-afa79636e324" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff2450ea-4048-4ccb-bc4e-afa79636e324")) {                    Plotly.newPlot(                        "ff2450ea-4048-4ccb-bc4e-afa79636e324",                        [{"x":["competition","significantly","multilingual","languages","information","structure","attractive","particular","effective","recognition","challenging","performance","individual","component","structures","bilingual","recurrent","desirable","egocentric","successive","understanding","segmenting","substantial","parameters","combinations","facilitates","implementing","activities","continuous","segmentation","unsupervised","retrieval","depicting","theoretical","connection","motivated","heuristic","interests","demonstrate","generalized","heuristics","functions","framework","different","instantiated","important","empirical","contextual","distribution","algorithms","importantly","logarithmic","diversification","translates","correlate","satisfaction","limitations","diversified","furthermore","classical","appropriately","importance","realistic","underlying","evaluation","appropriate","estimates","preferences","unification","consensus","difficulties","junctions","averaging","proportional","neutrosophic","combination","introduce","weighting","conjunctive","conditional","intersection","inclusion","disjunctive","conflicting","parameterized","following","exclusive","introducing","smarandache","dempsters","presenting","considering","comparison","classification","computational","algorithm","complexities","respectively","convergence","increases","perceptron","increased","drastically","propagation","introduced","multilayer","categorical","illustrate","conceptual","cognition","constructed","interacting","composite","adjectives","applications","relations","compositional","emphasizing","semantics","interactions","concurrent","experimental","capturing","individuals","integrates","superiority","specifically","combining","selectively","assumption","inferring","concerning","generating","observational","integrating","acyclicity","conditions","identifiability","techniques","sufficiency","observing","investigated","variables","knowledge","randomized","inference","intervening","faithfulness","statistics","determined","phenomenon","relationships","incorporating","discovery","establish","overlapping","collected","experiments","scientific","historical","influences","recommendation","describes","consequence","according","relevance","integrated","dimensional","maintaining","estimator","consistency","statistic","approaches","considerably","extension","decomposition","predicting","properties","nonlinearity","nonparametric","estimation","decomposing","regression","formulation","promoting","necessary","facilitate","completely","environment","conjugate","ingredient","computationally","resulting","variational","exploiting","hierarchical","iterative","extensive","presented","numerically"],"y":[30,264,25,97,688,323,27,268,245,368,273,878,121,125,132,7,146,29,10,18,153,23,51,256,35,14,27,42,108,207,135,93,4,155,34,60,66,18,558,80,44,213,507,773,7,343,163,57,255,585,29,11,3,5,5,21,58,2,176,112,8,84,73,106,249,85,82,41,5,11,29,4,27,10,3,145,336,17,5,93,17,13,6,11,25,89,4,52,3,2,28,56,136,494,290,828,17,84,130,53,19,45,20,65,146,16,8,73,18,12,69,15,11,3,417,92,22,3,96,70,8,398,47,35,20,36,171,97,9,70,29,15,97,6,41,3,137,5,367,2,21,53,122,327,30,218,1,2,64,39,21,77,54,47,41,19,69,603,40,19,12,30,86,22,118,35,49,175,44,17,54,11,421,27,84,77,65,214,4,20,196,9,118,77,4,72,45,42,127,7,4,77,155,56,73,96,86,168,169,16],"type":"bar"},{"x":["competition","significantly","multilingual","languages","information","structure","at ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4568,), (4568, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Performance</span> <span style='background-color:rgba(0, 255, 0, 0.4228571428571428);'>Evaluation</span> <span style=''>of</span> <span style=''>Edge</span> <span style=''>Directed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Interpolation</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>Images</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>high</span> <span style=''>visual</span> <span style=''>quality</span> <span style=''>but</span> <span style=''>fail</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>inability</span> <span style=''>to</span> <span style=''>preserve</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>Edges</span> <span style=''>carry</span> <span style=''>heavy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.5875831485587584);'>detection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determination</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>Edge</span> <span style=''>adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>become</span> <span style=''>a</span> <span style=''>center</span> <span style=''>of</span> <span style=''>focus</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>four</span> <span style=''>edge</span> <span style=''>directed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparing</span> <span style=''>with</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>traditional</span> <span style=''>methods</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3557692307692308);'>evaluated</span> <span style=''>on</span> <span style=''>two</span> <span style=''>groups</span> <span style=''>of</span> <span style=''>images</span> <span style=''>These</span> <span style=''>methods</span> <span style=''>include</span> <span style=''>new</span> <span style=''>edge</span> <span style=''>directed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>(NEDI)</span> <span style=''>edge</span> <span style=''>guided</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>(EGII)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>curvature</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>(ICBI)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directional</span> <span style=''>cubic</span> <span style='background-color:rgba(0, 255, 0, 0.6774193548387097);'>convolution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>(DCCI)</span> <span style=''>and</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>traditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Parzen</span> <span style=''>based</span> <span style=''>distance</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>measures</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>of</span> <span style=''>summary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computation</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Approximate</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computation</span> <span style=''>(ABC)</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>free</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>methods</span> <span style=''>ABC</span> <span style=''>methods</span> <span style=''>use</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>data</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>drew</span> <span style=''>from</span> <span style=''>a</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>and</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>process</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>a</span> <span style=''>distance</span> <span style=''>between</span> <span style=''>the</span> <span style=''>summary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>data</span> <span style=''>and</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>For</span> <span style=''>complex</span> <span style=''>models</span> <span style=''>it</span> <span style=''>is</span> <span style=''>usually</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>define</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>for</span> <span style=''>choosing</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructing</span> <span style=''>the</span> <span style=''>summary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>Recently</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>ABC</span> <span style=''>has</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dissimilarity</span> <span style=''>measure</span> <span style=''>between</span> <span style=''>discrete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>kernel</span> <span style='background-c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>and</span> <span style=''>Scalable</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Sparse</span> <span style=''>Changes</span> <span style=''>in</span> <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.3421052631578947);'>Dimensional</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Graphical</span> <span style=''>Model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <br/><br/><span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.323943661971831);'>estimating</span> <span style=''>the</span> <span style=''>change</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>of</span> <span style=''>two</span> <span style=''>p</span> <span style='background-color:rgba(255, 0, 0, 0.3421052631578947);'>dimensional</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Graphical</span> <span style=''>models</span> <span style=''>(GGMs)</span> <span style=''>Previous</span> <span style=''>studies</span> <span style=''>for</span> <span style=''>sparse</span> <span style=''>change</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>GGMs</span> <span style=''>involve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>non</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>DIFFEE</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.323943661971831);'>estimating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>DIFFerential</span> <span style=''>networks</span> <span style=''>via</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>Elementary</span> <span style='background-color:rgba(255, 0, 0, 0.7976190476190477);'>Estimator</span> <span style=''>under</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3421052631578947);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situation</span> <span style=''>DIFFEE</span> <span style=''>is</span> <span style=''>solved</span> <span style=''>through</span> <span style=''>a</span> <span style=''>faster</span> <span style=''>and</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>solution</span> <span style=''>that</span> <span style=''>enables</span> <span style=''>it</span> <span style=''>to</span> <span style=''>work</span> <span style=''>in</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>settings</span> <span style=''>We</span> <span style=''>conduct</span> <span style=''>a</span> <span style=''>rigorous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistical</span> <span style=''>analysis</span> <span style=''>showing</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surprisingly</span> <span style=''>DIFFEE</span> <span style=''>achieves</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(255, 0, 0, 0.5702479338842976);'>asymptotic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rates</span> <span style=''>as</span> <span style=''>the</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Predicting</span> <span style=''>clicks</span> <span style=''>in</span> <span style=''>online</span> <span style=''>display</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advertising</span> <span style=''>with</span> <span style=''>latent</span> <span style=''>features</span> <span style=''>and</span> <span style=''>side</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <br/><br/><span style=''>We</span> <span style=''>review</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style=''>click</span> <span style=''>through</span> <span style=''>rate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>work</span> <span style=''>of</span> <span style=''>Menon</span> <span style=''>et</span> <span style=''>al</span> <span style=''>11</span> <span style=''>which</span> <span style=''>combines</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collaborative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>and</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>with</span> <span style=''>a</span> <span style=''>side</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>model</span> <span style=''>and</span> <span style=''>fuses</span> <span style=''>the</span> <span style=''>outputs</span> <span style=''>to</span> <span style=''>proper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>in</span> <span style=''>01</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>details</span> <span style=''>both</span> <span style=''>for</span> <span style=''>the</span> <span style=''>modeling</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>part</span> <span style=''>that</span> <span style=''>are</span> <span style=''>not</span> <span style=''>found</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>elsewhere</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rigorously</span> <span style=''>test</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>several</span> <span style=''>test</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consecutive</span> <span style=''>days</span> <span style=''>in</span> <span style=''>a</span> <span style=''>click</span> <span style=''>through</span> <span style=''>rate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>setup</span> <span style=''>in</span> <span style=''>a</span> <span style=''>manner</span> <span style=''>which</span> <span style=''>reflects</span> <span style=''>a</span> <span style=''>real</span> <span style=''>world</span> <span style=''>pipeline</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>confirm</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style=''>using</span> <span style=''>latent</span> <span style=''>features</span> <span style=''>albeit</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differences</span> <span style=''>in</span> <span style=''>the</span> <span style=''>measures</span> <spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07160669754185964)
# 	architecture (0.07873174207338796)
# 	challenging (0.09725685785536159)
# 	experimental (0.1417883861774136)
# 	information (0.2451015318845743)
# 	segmentation (0.07374421090131814)
# 	different (0.27538297114356963)
# 	detection (0.12753829711435696)
# 	recognition (0.13110081938012114)
# 	convolutional (0.1278945493409334)
#
# Some Statistics words are:
# 	statistical (0.15203211239337683)
# 	stochastic (0.1364776718514802)
# 	variables (0.14249874560963371)
# 	distribution (0.19016557952834923)
# 	algorithm (0.39789262418464627)
# 	theoretical (0.15905669844455594)
# 	estimation (0.1741093828399398)
# 	dimensional (0.17912694430506773)
# 	regression (0.16859006522829906)
# 	inference (0.20722528850978425)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c24a1e6f-feeb-41aa-b8a2-8b0510b3f6f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c24a1e6f-feeb-41aa-b8a2-8b0510b3f6f8")) {                    Plotly.newPlot(                        "c24a1e6f-feeb-41aa-b8a2-8b0510b3f6f8",                        [{"x":["competition","significantly","multilingual","languages","information","structure","attractive","particular","effective","recognition","challenging","performance","individual","component","structures","bilingual","recurrent","desirable","egocentric","successive","understanding","segmenting","substantial","parameters","combinations","facilitates","implementing","activities","continuous","segmentation","unsupervised","retrieval","depicting","theoretical","connection","motivated","heuristic","interests","demonstrate","generalized","heuristics","functions","framework","different","instantiated","important","empirical","contextual","distribution","algorithms","importantly","logarithmic","diversification","translates","correlate","satisfaction","limitations","diversified","furthermore","classical","appropriately","importance","realistic","underlying","evaluation","appropriate","estimates","preferences","unification","consensus","difficulties","junctions","averaging","proportional","neutrosophic","combination","introduce","weighting","conjunctive","conditional","intersection","inclusion","disjunctive","conflicting","parameterized","following","exclusive","introducing","smarandache","dempsters","presenting","considering","comparison","classification","computational","algorithm","complexities","respectively","convergence","increases","perceptron","increased","drastically","propagation","introduced","multilayer","categorical","illustrate","conceptual","cognition","constructed","interacting","composite","adjectives","applications","relations","compositional","emphasizing","semantics","interactions","concurrent","experimental","capturing","individuals","integrates","superiority","specifically","combining","selectively","assumption","inferring","concerning","generating","observational","integrating","acyclicity","conditions","identifiability","techniques","sufficiency","observing","investigated","variables","knowledge","randomized","inference","intervening","faithfulness","statistics","determined","phenomenon","relationships","incorporating","discovery","establish","overlapping","collected","experiments","scientific","historical","influences","recommendation","describes","consequence","according","relevance","integrated","dimensional","maintaining","estimator","consistency","statistic","approaches","considerably","extension","decomposition","predicting","properties","nonlinearity","nonparametric","estimation","decomposing","regression","formulation","promoting","necessary","facilitate","completely","environment","conjugate","ingredient","computationally","resulting","variational","exploiting","hierarchical","iterative","extensive","presented","numerically","equivalent","probability","simulation","effectiveness","counterparts","processing","eliminate","posteriori","posterior","automated","identification","regularized","parameter","deterministic","perspective","iteration","clustering","synthetic","supervised","investigate","efficient","comparisons","backtracking","measurements","therefore","partially","household","disadvantage","simulations","decisions","consequential","confounding","decreases","homogeneity","algorithmically","confounded","algorithmic","expanding","identified","automatically","dependent","background","orientation","consistent","performed","orientations","independent","benchmarks","containing","particularly","probabilistic","correctly","irrespective","translation","o ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonparametrics
# 	intimately
# 	concordant
# 	statisticians
# 	sparsistency
# 	accounted
# 	centering
# 	orthogonality
# 	hermitian
# 	undersampling
# 	assimilated
# 	assimilation
# 	enumerated
# 	selectors
# 	mislabeled
# 	noninvasive
# 	spectrometry
# 	ergodicity
# 	symplectic
# 	nonparanormal
# Some words which never appear in Statistics papers:
# 	bilingual
# 	depicting
# 	diversification
# 	junctions
# 	neutrosophic
# 	smarandache
# 	dempsters
# 	adjectives
# 	consequential
# 	instructions
# 	binocular
# 	attentional
# 	restructuring
# 	multiplex
# 	monocular
# 	relocalization
# 	discarded
# 	insertion
# 	declarative
# 	summarisation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.063913229977327e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7525
